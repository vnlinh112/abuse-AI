# %% [markdown]
# **FIT3183 Malicious AI & Dark Side Security**
# # Lab 3: Deepfakes I
#
# Try this task:
# * Explore **First Order Motion Model** for Image Animation
#
# 👉 ***Copy this Colab notebook to your Drive***, read the instruction and fill the missing code.
#
# 👉 ***Use GPU:*** `Runtime > Change runtime type > GPU`.
#
# *Note: If you are new to Google Colab and Pytorch: please read this [Pre-lab Activities](https://drive.google.com/file/d/1aBOkxvGxkOeZlZxYQy0xiEzdEwU-C1DX/view?usp=sharing) first.*
#
# <small>*Prepared by [Linh Vu](mailto:linh.vu@monash.edu) (Lab Tutor) Aug 2020.*

# %% [markdown]
# ## Task 1: Explore First Order Motion Model for Image Animation
#
# *Reference: [First Order Motion Model for Image Animation](https://papers.nips.cc/paper/8935-first-order-motion-model-for-image-animation), NIPS 2019.*

# %% [markdown]
# ### Setup First Order Motion Model
#
# Clone the code from this [Github](https://github.com/AliaksandrSiarohin/first-order-model).

# %%
## YOUR CODE HERE ##

# %%
cd first-order-model

# %% [markdown]
# **Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# **Copy this folder (or add a shortcut) https://drive.google.com/drive/folders/1g5k4vLKlfmbB7MGA3TX1TBep9zGvJudg?usp=sharing to your Google Drive.** It contains the pretrained model and some images and videos...

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")
from demo import load_checkpoints
from skimage import img_as_ubyte

# create model and load checkpoints

generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='/content/gdrive/My Drive/3183_lab3/vox-cpk.pth.tar')

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani

# %% [markdown]
# Call the `make_animation` from file `demo.py` to create the animated image from the source image and driving video.

# %%
## YOUR CODE HERE ##

# Load the make_animation function from demo.py (1 line)


## END YOUR CODE HERE ##

def test_deepfake(source_image_path, driving_video_path, result_video_name='generated.mp4'):
  source_image = imageio.imread(source_image_path)
  driving_video = imageio.mimread(driving_video_path)

  # Resize image and video to 256x256
  source_image = resize(source_image, (256, 256))[..., :3]
  driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

  ## YOUR CODE HERE ##

  # Create the animated image with make_animation (1 line)
  # predictions = ...

  ## END YOUR CODE HERE ##

  # Save the result  
  imageio.mimsave(result_video_name, [img_as_ubyte(frame) for frame in predictions])
  result = display(source_image, driving_video, predictions).to_html5_video()
  
  return result

# %% [markdown]
# Let's try to create our first deepfake animated image:

# %%
generated1 = test_deepfake(source_image_path='/content/gdrive/My Drive/3183_lab3/sources/monalisa_400.jpg', 
              driving_video_path='/content/gdrive/My Drive/3183_lab3/sources/taylor_delicate_funny_crop3.mp4',
              result_video_name='generated1.mp4')
HTML(generated1)

# %% [markdown]
# You can try with different images. The driving video can be mp4 or gif. Notice how the quality of the result change based on the size and the direction of the face in the source image and the driving video.

# %%
## YOUR CODE HERE ##

# %%
## YOUR CODE HERE ##

# %% [markdown]
# ### Automatically crop face from Image and Video

# %% [markdown]
# Think of how to automatically crop face from image and video using Open CV.
